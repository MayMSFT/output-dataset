# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/MachineLearningNotebooks/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-how-to-use-estimatorstep.png)

# %% [markdown]
# # How to use EstimatorStep in AML Pipeline
#
# This notebook shows how to use the EstimatorStep with Azure Machine Learning Pipelines. Estimator is a convenient object in Azure Machine Learning that wraps run configuration information to help simplify the tasks of specifying how a script is executed.
#
#
# ## Prerequisite:
# * Understand the [architecture and terms](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture) introduced by Azure Machine Learning
# * If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, go through the [configuration notebook](https://aka.ms/pl-config) to:
#     * install the AML SDK
#     * create a workspace and its configuration file (`config.json`)

# %% [markdown]
# Let's get started. First let's import some Python libraries.

# %%
import azureml.core
# check core SDK version number
print("Azure ML SDK Version: ", azureml.core.VERSION)
# Out:
# Azure ML SDK Version:  0.1.0.15477075

# %% [markdown]
# ## Initialize workspace
# Initialize a [Workspace](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#workspace) object from the existing workspace you created in the Prerequisites step. `Workspace.from_config()` creates a workspace object from the details stored in `config.json`.

# %%
from azureml.core import Workspace
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# WARNING - Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# Workspace name: centraleuap
# Azure region: centraluseuap
# Subscription id: 35f16a99-532a-4a47-9e93-00305f6c40f2
# Resource group: rongduan-dev

# %% [markdown]
# ## Create or Attach existing AmlCompute
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for training your model. In this tutorial, you create `AmlCompute` as your training compute resource.

# %% [markdown]
# If we could not find the cluster with the given name, then we will create a new cluster here. We will create an `AmlCompute` cluster of `STANDARD_NC6` GPU VMs. This process is broken down into 3 steps:
# 1. create the configuration (this step is local and only takes a second)
# 2. create the cluster (this step will take about **20 seconds**)
# 3. provision the VMs to bring the cluster to the initial size (of 1 in this case). This step will take about **3-5 minutes** and is providing only sparse output in the process. Please make sure to wait until the call returns before moving to the next cell

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "mlc"

try:
    cpu_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_NC6', max_nodes=4)

    # create the cluster
    cpu_cluster = ComputeTarget.create(ws, cluster_name, compute_config)

    # can poll for a minimum number of nodes and for a specific timeout. 
    # if no min node count is provided it uses the scale settings for the cluster
    cpu_cluster.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)

# use get_status() to get a detailed status for the current cluster. 
print(cpu_cluster.get_status().serialize())
# Out:
# Found existing compute target
# {'currentNodeCount': 1, 'targetNodeCount': 1, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 1, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Steady', 'allocationStateTransitionTime': '2020-06-02T04:14:32.924000+00:00', 'errors': None, 'creationTime': '2019-10-22T00:19:09.957713+00:00', 'modifiedTime': '2020-06-09T04:37:06.725202+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 1, 'maxNodeCount': 10, 'nodeIdleTimeBeforeScaleDown': 'PT3600S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_D2_V2'}

# %% [markdown]
# Now that you have created the compute target, let's see what the workspace's `compute_targets` property returns. You should now see one entry named 'cpu-cluster' of type `AmlCompute`.

# %% [markdown]
# ## Use a simple script
# We have already created a simple "hello world" script. This is the script that we will submit through the estimator pattern. It prints a hello-world message, and if Azure ML SDK is installed, it will also logs an array of values ([Fibonacci numbers](https://en.wikipedia.org/wiki/Fibonacci_number)).

# %% [markdown]
# ## Build an Estimator object
# Estimator by default will attempt to use Docker-based execution. You can also enable Docker and let estimator pick the default CPU image supplied by Azure ML for execution. You can target an AmlCompute cluster (or any other supported compute target types). You can also customize the conda environment by adding conda and/or pip packages.
#
# > Note: The arguments to the entry script used in the Estimator object should be specified as *list* using
#     'estimator_entry_script_arguments' parameter when instantiating EstimatorStep. Estimator object's parameter
#     'script_params' accepts a dictionary. However 'estimator_entry_script_arguments' parameter expects arguments as
#     a list.
#
# > Estimator object initialization involves specifying a list of DataReference objects in its 'inputs' parameter.
#     In Pipelines, a step can take another step's output or DataReferences as input. So when creating an EstimatorStep,
#     the parameters 'inputs' and 'outputs' need to be set explicitly and that will override 'inputs' parameter
#     specified in the Estimator object.
#
# > The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.

# %%
from azureml.core import Datastore, Dataset
from azureml.data import OutputFileDatasetConfig

def_blob_store = Datastore(ws, "workspaceblobstore")

input_data = Dataset.File.from_files(def_blob_store.path('iris.csv')).as_named_input('input').as_mount()
output = OutputFileDatasetConfig(destination=(def_blob_store, 'may_sample/outputdataset'))

source_directory = 'estimator_train'
# Out:
# WARNING - This is an experimental class, and may change at any time. For more information, see (https://aka.ms/azuremlexperimental).
# WARNING - method __init__: This is an experimental method, and may change at any time. For more information, see (https://aka.ms/azuremlexperimental).
# WARNING - This is an experimental class, and may change at any time. For more information, see (https://aka.ms/azuremlexperimental).
# WARNING - method __init__: This is an experimental method, and may change at any time. For more information, see (https://aka.ms/azuremlexperimental).

# %%
from azureml.core import Environment
from azureml.core.conda_dependencies import CondaDependencies

conda_env = Environment('conda-env')
conda_env.python.conda_dependencies = CondaDependencies.create(pip_packages=['azureml-sdk<0.1.1'],
                                                               pip_indexurl='https://azuremlsdktestpypi.azureedge.net/Create-Dev-Index/15335858/')

# %%
from azureml.train.estimator import Estimator

est = Estimator(source_directory=source_directory, 
                compute_target=cpu_cluster, 
                entry_script='dummy_train.py', 
                environment_definition=conda_env)

# %% [markdown]
# ## Create an EstimatorStep
# [EstimatorStep](https://docs.microsoft.com/en-us/python/api/azureml-pipeline-steps/azureml.pipeline.steps.estimator_step.estimatorstep?view=azure-ml-py) adds a step to run Estimator in a Pipeline.
#
# - **name:** Name of the step
# - **estimator:** Estimator object
# - **estimator_entry_script_arguments:**
# - **runconfig_pipeline_params:** Override runconfig properties at runtime using key-value pairs each with name of the runconfig property and PipelineParameter for that property
# - **inputs:** Inputs
# - **outputs:** Output is list of PipelineData
# - **compute_target:** Compute target to use
# - **allow_reuse:** Whether the step should reuse previous results when run with the same settings/inputs. If this is false, a new run will always be generated for this step during pipeline execution.
# - **version:** Optional version tag to denote a change in functionality for the step

# %%
from azureml.pipeline.steps import EstimatorStep

est_step = EstimatorStep(name="Estimator_Train", 
                         estimator=est, 
                         estimator_entry_script_arguments=["--datadir", input_data, "--output", output],
                         compute_target=cpu_cluster)

# %% [markdown]
# ## Build and Submit the Experiment

# %%
from azureml.pipeline.core import Pipeline
from azureml.core import Experiment
pipeline = Pipeline(workspace=ws, steps=[est_step])
pipeline_run = Experiment(ws, 'Estimator_sample').submit(pipeline)
# Out:
# Created step Estimator_Train [e6719891][9a595dbf-0d83-4fad-ac92-98bf93b92a1f], (This step will run and generate new outputs)
# Submitted PipelineRun 4d72c644-9f57-4352-b110-1c774e1f6956
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Estimator_sample/runs/4d72c644-9f57-4352-b110-1c774e1f6956?wsid=/subscriptions/35f16a99-532a-4a47-9e93-00305f6c40f2/resourcegroups/rongduan-dev/workspaces/centraleuap

# %% [markdown]
# ## View Run Details

# %%
pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 4d72c644-9f57-4352-b110-1c774e1f6956
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Estimator_sample/runs/4d72c644-9f57-4352-b110-1c774e1f6956?wsid=/subscriptions/35f16a99-532a-4a47-9e93-00305f6c40f2/resourcegroups/rongduan-dev/workspaces/centraleuap
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: bc9d6dd3-f571-4636-be40-6e3d9ef96ab9
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Estimator_sample/runs/bc9d6dd3-f571-4636-be40-6e3d9ef96ab9?wsid=/subscriptions/35f16a99-532a-4a47-9e93-00305f6c40f2/resourcegroups/rongduan-dev/workspaces/centraleuap
# StepRun( Estimator_Train ) Status: NotStarted
# StepRun( Estimator_Train ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2020/06/09 18:47:44 Downloading source code...
# 2020/06/09 18:47:49 Finished downloading source code
# 2020/06/09 18:47:49 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/06/09 18:47:50 Successfully set up Docker network: acb_default_network
# 2020/06/09 18:47:50 Setting up Docker configuration...
# 2020/06/09 18:47:50 Successfully set up Docker configuration
# 2020/06/09 18:47:50 Logging in to registry: centraleacrmpnfcrek.azurecr.io
# 2020/06/09 18:47:51 Successfully logged into centraleacrmpnfcrek.azurecr.io
# 2020/06/09 18:47:51 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/06/09 18:47:51 Scanning for dependencies...
# 2020/06/09 18:47:52 Successfully scanned dependencies
# 2020/06/09 18:47:52 Launching container with name: acb_step_0
# Sending build context to Docker daemon  60.93kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# Digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1@sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#  ---> a0dab4f7c804
# Step 2/15 : USER root
#  ---> Running in cb19dda046f7
# Removing intermediate container cb19dda046f7
#  ---> e1ff40d18a41
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 1e638e66bca6
# Removing intermediate container 1e638e66bca6
#  ---> b9350167e629
# Step 4/15 : WORKDIR /
#  ---> Running in b1857108ab25
# Removing intermediate container b1857108ab25
#  ---> 91e178ea854a
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d63af9acd664
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in de1171e23686
# Removing intermediate container de1171e23686
#  ---> 2f87cf6868db
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> d889d7aaa563
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 302a24e3bf24
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# pip-20.0.2           | 1.9 MB    |            |   0%
# pip-20.0.2           | 1.9 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# tk-8.6.8             | 3.1 MB    |            |   0%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##9        |  30%
# python-3.6.2         | 27.0 MB   | ######5    |  65%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# wheel-0.34.2         | 49 KB     |            |   0%
# wheel-0.34.2         | 49 KB     | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# certifi-2020.4.5.1   | 159 KB    |            |   0%
# certifi-2020.4.5.1   | 159 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libffi-3.2.1         | 43 KB     |            |   0%
# libffi-3.2.1         | 43 KB     | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #########6 |  96%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# setuptools-47.1.1    | 653 KB    |            |   0%
# setuptools-47.1.1    | 653 KB    | ########## | 100%
#
# ca-certificates-2020 | 132 KB    |            |   0%
# ca-certificates-2020 | 132 KB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.ab1bdenk.requirements.txt']
# Pip subprocess output:
# Looking in indexes: https://azuremlsdktestpypi.azureedge.net/Create-Dev-Index/15335858/, https://pypi.python.org/simple
# Collecting azureml-sdk~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_sdk-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=uRxaPtd8DSeuAv3YKwNWvN3%2BetlIkylsEDbqciwnr9k%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (4.5 kB)
# Collecting azureml-core~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_core-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=CfL%2BtNirYLUJD3uGxPbQ2g2g6klnjaKM4n4TZp1ooG0%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (1.5 MB)
# Collecting azureml-train~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_train-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=sBeIuQrXYe9kYcqSpPexKXksbuAY8i7zpF%2Bi%2BcAUhxc%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (3.4 kB)
# Collecting azureml-pipeline~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_pipeline-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=4eLBqyz%2FJTqih%2BOSGtaaRs7EKeI0cARCaFyq1%2B%2FcQg4%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (3.8 kB)
# Collecting azureml-train-automl-client~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_train_automl_client-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=mjAnHxdFg8JQd1Aym%2F2Tr4GacMnUFqDMJ5fdkHPHY70%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (89 kB)
# Collecting azureml-dataprep[fuse]<1.8.0a,>=1.7.0a
#   Downloading https://dataprepdownloads.azureedge.net/install/wheels/daily-001996AEA44B4B4CA18D726613/0.1.2006.08011/win/ship/azureml_dataprep-1.7.1a2020060801-py3-none-any.whl (27.6 MB)
# Collecting azure-mgmt-storage>=1.5.0
#   Downloading azure_mgmt_storage-10.0.0-py2.py3-none-any.whl (532 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.16-py2.py3-none-any.whl (84 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-2.9.2-cp35-abi3-manylinux2010_x86_64.whl (2.7 MB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.3-py2.py3-none-any.whl (40 kB)
# Collecting PyJWT
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting azure-mgmt-keyvault>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pytz
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.25.9-py2.py3-none-any.whl (126 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.25-py2.py3-none-any.whl (12 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.1.2-py3-none-any.whl (14 kB)
# Collecting azure-mgmt-authorization>=0.40.0
#   Downloading azure_mgmt_authorization-0.60.0-py2.py3-none-any.whl (82 kB)
# Collecting azure-mgmt-network~=10.0
#   Downloading azure_mgmt_network-10.2.0-py2.py3-none-any.whl (8.6 MB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-graphrbac>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ruamel.yaml>0.16.7
#   Downloading ruamel.yaml-0.16.10-py2.py3-none-any.whl (111 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.4-py2.py3-none-any.whl (55 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.0-py2.py3-none-any.whl (28 kB)
# Collecting docker
#   Downloading docker-4.2.1-py2.py3-none-any.whl (143 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource>=1.2.1
#   Downloading azure_mgmt_resource-10.0.0-py2.py3-none-any.whl (809 kB)
# Collecting pyopenssl
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting azureml-train-core~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_train_core-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=V60NVGKd7jrCGg1DpNPyvrs33hFC9RxzAvEhwwU%2FARQ%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (8.6 MB)
# Collecting azureml-pipeline-steps~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_pipeline_steps-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=JPm8c0ls3Ckkoz5p9eOXyk4gp67dpGdMN7oKwkLY1Lo%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (58 kB)
# Collecting azureml-pipeline-core~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_pipeline_core-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=AIrgL26LcQV5JvWpe4SRqzgC4bVJrDoAxNzyEtAdqT8%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (294 kB)
# Collecting azureml-automl-core~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_automl_core-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=ynT4tbtQMc4kThFzm2kEugXO4R3BU5P%2ByscxK5hk%2BQ8%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (131 kB)
# Collecting azureml-telemetry~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_telemetry-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=aWjf%2BBIa8qx4rm2IUj0G0rPe7HxnO4%2BtTNrEGaoed6Q%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (29 kB)
# Collecting azure-identity<1.3.0,>=1.2.0
#   Downloading azure_identity-1.2.0-py2.py3-none-any.whl (58 kB)
# Collecting azureml-dataprep-native<15.0.0,>=14.2.0
#   Downloading https://dataprepdownloads.azureedge.net/install/wheels/daily-001996AEA44B4B4CA18D726613/0.1.2006.08011/linux/ship/azureml_dataprep_native-14.2.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle>=1.1.0
#   Downloading cloudpickle-1.4.1-py3-none-any.whl (26 kB)
# Collecting dotnetcore2>=2.1.14
#   Downloading dotnetcore2-2.1.14-py3-none-manylinux1_x86_64.whl (29.3 MB)
# Collecting fusepy>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=0.1.0.15477075->azureml-sdk~=0.1.0.15477075->-r /azureml-environment-setup/condaenv.ab1bdenk.requirements.txt (line 3)) (2020.4.5.1)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.0-cp36-cp36m-manylinux1_x86_64.whl (399 kB)
# Collecting six>=1.4.1
#   Downloading six-1.15.0-py2.py3-none-any.whl (10 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-1.6.1-py2.py3-none-any.whl (31 kB)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.4.3-py3-none-any.whl (21 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.0-cp36-cp36m-manylinux1_x86_64.whl (548 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting flake8<=3.7.9,>=3.1.0; python_version >= "3.6"
#   Downloading flake8-3.7.9-py2.py3-none-any.whl (69 kB)
# Collecting azureml-train-restclients-hyperdrive~=0.1.0.15477075
#   Downloading https://azuremlsdktestpypi.blob.core.windows.net/repo/Create-Dev-Index/15335858/azureml_train_restclients_hyperdrive-0.1.0.15477075-py3-none-any.whl?sv=2018-03-28&sr=b&sig=NmdVqPwkWH%2BpJicB94WfYVGMnBGnnFD8Sau1yaS%2FPx8%3D&st=2020-06-08T21%3A05%3A33Z&se=2021-06-08T21%3A05%3A33Z&sp=rl (19 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.6.0-py2.py3-none-any.whl (120 kB)
# Collecting msal-extensions~=0.1.3
#   Downloading msal_extensions-0.1.3-py2.py3-none-any.whl (9.0 kB)
# Collecting msal<2.0.0,>=1.0.0
#   Downloading msal-1.3.0-py2.py3-none-any.whl (48 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.1.0-py3-none-any.whl (4.9 kB)
# Collecting entrypoints<0.4.0,>=0.3.0
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting mccabe<0.7.0,>=0.6.0
#   Downloading mccabe-0.6.1-py2.py3-none-any.whl (8.6 kB)
# Collecting pycodestyle<2.6.0,>=2.5.0
#   Downloading pycodestyle-2.5.0-py2.py3-none-any.whl (51 kB)
# Collecting pyflakes<2.2.0,>=2.1.0
#   Downloading pyflakes-2.1.1-py2.py3-none-any.whl (59 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.0-py2.py3-none-any.whl (14 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10503 sha256=4820781577a61491f0d32e14e981d10e89f3c197bb194057843fb0b1d045583b
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: chardet, idna, urllib3, requests, pycparser, cffi, six, cryptography, PyJWT, python-dateutil, adal, isodate, oauthlib, requests-oauthlib, msrest, msrestazure, azure-common, azure-mgmt-storage, azure-mgmt-containerregistry, contextlib2, azure-mgmt-keyvault, backports.weakref, backports.tempfile, pytz, zipp, importlib-metadata, jsonpickle, jeepney, SecretStorage, azure-mgmt-authorization, azure-mgmt-network, pyasn1, pyopenssl, ndg-httpsclient, azure-graphrbac, ruamel.yaml.clib, ruamel.yaml, pathspec, websocket-client, docker, jmespath, azure-mgmt-resource, azureml-core, entrypoints, mccabe, pycodestyle, pyflakes, flake8, azureml-train-restclients-hyperdrive, applicationinsights, azureml-telemetry, azureml-train-core, azureml-train, azure-core, portalocker, msal, msal-extensions, azure-identity, azureml-dataprep-native, cloudpickle, distro, dotnetcore2, fusepy, azureml-dataprep, azureml-automl-core, azureml-train-automl-client, azureml-pipeline-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
# Successfully installed PyJWT-1.7.1 SecretStorage-3.1.2 adal-1.2.4 applicationinsights-0.11.9 azure-common-1.1.25 azure-core-1.6.0 azure-graphrbac-0.61.1 azure-identity-1.2.0 azure-mgmt-authorization-0.60.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-network-10.2.0 azure-mgmt-resource-10.0.0 azure-mgmt-storage-10.0.0 azureml-automl-core-0.1.0.15477075 azureml-core-0.1.0.15477075 azureml-dataprep-1.7.1a2020060801 azureml-dataprep-native-14.2.0 azureml-pipeline-0.1.0.15477075 azureml-pipeline-core-0.1.0.15477075 azureml-pipeline-steps-0.1.0.15477075 azureml-sdk-0.1.0.15477075 azureml-telemetry-0.1.0.15477075 azureml-train-0.1.0.15477075 azureml-train-automl-client-0.1.0.15477075 azureml-train-core-0.1.0.15477075 azureml-train-restclients-hyperdrive-0.1.0.15477075 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.0 chardet-3.0.4 cloudpickle-1.4.1 contextlib2-0.6.0.post1 cryptography-2.9.2 distro-1.5.0 docker-4.2.1 dotnetcore2-2.1.14 entrypoints-0.3 flake8-3.7.9 fusepy-3.0.1 idna-2.9 importlib-metadata-1.6.1 isodate-0.6.0 jeepney-0.4.3 jmespath-0.10.0 jsonpickle-1.4.1 mccabe-0.6.1 msal-1.3.0 msal-extensions-0.1.3 msrest-0.6.16 msrestazure-0.6.3 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pathspec-0.8.0 portalocker-1.7.0 pyasn1-0.4.8 pycodestyle-2.5.0 pycparser-2.20 pyflakes-2.1.1 pyopenssl-19.1.0 python-dateutil-2.8.1 pytz-2020.1 requests-2.23.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.10 ruamel.yaml.clib-0.2.0 six-1.15.0 urllib3-1.25.9 websocket-client-0.57.0 zipp-3.1.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 302a24e3bf24
#  ---> 1fac65cea366
# Step 9/15 : ENV PATH /azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126/bin:$PATH
#  ---> Running in 7963c3d2327b
# Removing intermediate container 7963c3d2327b
#  ---> 03e91e230aed
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126
#  ---> Running in f5384c68361f
# Removing intermediate container f5384c68361f
#  ---> d0811d3d539c
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_becb75071dac89d1dfc4639fd26ab126/lib:$LD_LIBRARY_PATH
#  ---> Running in 11f74fc61a77
# Removing intermediate container 11f74fc61a77
#  ---> 746a2eee1dff
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> b6b75c0bd157
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 4a9f7937eb09
# Removing intermediate container 4a9f7937eb09
#  ---> 7983055b2d4c
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in f00272285b4f
# Removing intermediate container f00272285b4f
#  ---> d09abb4c5a41
# Step 15/15 : CMD ["bash"]
#  ---> Running in 29a8ac9ff3d5
# Removing intermediate container 29a8ac9ff3d5
#  ---> dee36fe5ad8a
# Successfully built dee36fe5ad8a
# Successfully tagged centraleacrmpnfcrek.azurecr.io/azureml/azureml_2ab4fbb8a091f131809d127ace412fcb:latest
# 2020/06/09 18:50:24 Successfully executed container: acb_step_0
# 2020/06/09 18:50:24 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/06/09 18:50:24 Pushing image: centraleacrmpnfcrek.azurecr.io/azureml/azureml_2ab4fbb8a091f131809d127ace412fcb:latest, attempt 1
# The push refers to repository [centraleacrmpnfcrek.azurecr.io/azureml/azureml_2ab4fbb8a091f131809d127ace412fcb]
# e97c6ced208e: Preparing
# 65b634885265: Preparing
# cd1143109017: Preparing
# dbcd05bd56a2: Preparing
# 844bfbfcd4c6: Preparing
# 7516f7043d11: Preparing
# f5aa53607bc1: Preparing
# 07eae5ad8c0b: Preparing
# facf43cddd83: Preparing
# 69a9bdc813b0: Preparing
# 7e2b9752143f: Preparing
# 63a67842a4c7: Preparing
# ae3a847dbd6b: Preparing
# 4ae3adcb66cb: Preparing
# aa6685385151: Preparing
# 0040d8f00d7e: Preparing
# 9e6f810a2aab: Preparing
# 7516f7043d11: Waiting
# 7e2b9752143f: Waiting
# 63a67842a4c7: Waiting
# f5aa53607bc1: Waiting
# 07eae5ad8c0b: Waiting
# ae3a847dbd6b: Waiting
# facf43cddd83: Waiting
# 4ae3adcb66cb: Waiting
# 69a9bdc813b0: Waiting
# aa6685385151: Waiting
# 9e6f810a2aab: Waiting
# 0040d8f00d7e: Waiting
# cd1143109017: Pushed
# 844bfbfcd4c6: Pushed
# dbcd05bd56a2: Pushed
# e97c6ced208e: Pushed
# 7516f7043d11: Pushed
# f5aa53607bc1: Pushed
# 07eae5ad8c0b: Pushed
# 63a67842a4c7: Pushed
# facf43cddd83: Pushed
# 4ae3adcb66cb: Pushed
# 69a9bdc813b0: Pushed
# 7e2b9752143f: Pushed
# aa6685385151: Pushed
# 0040d8f00d7e: Pushed
# ae3a847dbd6b: Pushed
# 9e6f810a2aab: Pushed
# 65b634885265: Pushed
# latest: digest: sha256:67623d337bdb414383e78b42033add4490e443f89480c81603e9b634cde973a5 size: 3883
# 2020/06/09 18:51:43 Successfully pushed image: centraleacrmpnfcrek.azurecr.io/azureml/azureml_2ab4fbb8a091f131809d127ace412fcb:latest
# 2020/06/09 18:51:43 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 152.698409)
# 2020/06/09 18:51:43 Populating digests for step ID: acb_step_0...
# 2020/06/09 18:51:45 Successfully populated digests for step ID: acb_step_0
# 2020/06/09 18:51:45 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 79.155105)
# 2020/06/09 18:51:45 The following dependencies were found:
# 2020/06/09 18:51:45
# - image:
#     registry: centraleacrmpnfcrek.azurecr.io
#     repository: azureml/azureml_2ab4fbb8a091f131809d127ace412fcb
#     tag: latest
#     digest: sha256:67623d337bdb414383e78b42033add4490e443f89480c81603e9b634cde973a5
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20200423.v1
#     digest: sha256:a8f6491296cbc183e95e9de29b59098e97d50ea87b4f1afa93e2afd43afeaf6d
#   git: {}
#
# Run ID: ca5w was successful after 4m4s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_e3f60327d6e8a7e7008ccb0fc8765117f97b4b0e710094c0c87f2832aa3edeee_d.txt
# ========================================================================================================================
# 2020-06-09T18:53:58Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2020-06-09T18:53:58Z Starting output-watcher...
# 2020-06-09T18:53:59Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2020-06-09T18:53:59Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2ab4fbb8a091f131809d127ace412fcb
# fe703b657a32: Pulling fs layer
# f9df1fafd224: Pulling fs layer
# a645a4b887f9: Pulling fs layer
# 57db7fe0b522: Pulling fs layer
# 20b5fabe4f63: Pulling fs layer
# 22898513a7dc: Pulling fs layer
# b77f65fcd9d7: Pulling fs layer
# 132ebd5cd5ca: Pulling fs layer
# 01991399be72: Pulling fs layer
# 60c58ca14ef7: Pulling fs layer
# ca339bb1ce1b: Pulling fs layer
# 00cf30d6c3d7: Pulling fs layer
# 078f888cc2c3: Pulling fs layer
# 87388bef588c: Pulling fs layer
# a5e3d82f1dff: Pulling fs layer
# aabda8a3d51f: Pulling fs layer
# 2363c3a4ec9d: Pulling fs layer
# 57db7fe0b522: Waiting
# 20b5fabe4f63: Waiting
# 22898513a7dc: Waiting
# b77f65fcd9d7: Waiting
# 132ebd5cd5ca: Waiting
# 01991399be72: Waiting
# 60c58ca14ef7: Waiting
# ca339bb1ce1b: Waiting
# 00cf30d6c3d7: Waiting
# 078f888cc2c3: Waiting
# 87388bef588c: Waiting
# a5e3d82f1dff: Waiting
# aabda8a3d51f: Waiting
# 2363c3a4ec9d: Waiting
# f9df1fafd224: Verifying Checksum
# f9df1fafd224: Download complete
# a645a4b887f9: Verifying Checksum
# a645a4b887f9: Download complete
# 57db7fe0b522: Verifying Checksum
# 57db7fe0b522: Download complete
# fe703b657a32: Verifying Checksum
# fe703b657a32: Download complete
# 20b5fabe4f63: Verifying Checksum
# 20b5fabe4f63: Download complete
# 22898513a7dc: Verifying Checksum
# 22898513a7dc: Download complete
# b77f65fcd9d7: Verifying Checksum
# b77f65fcd9d7: Download complete
# 60c58ca14ef7: Verifying Checksum
# 60c58ca14ef7: Download complete
# ca339bb1ce1b: Verifying Checksum
# ca339bb1ce1b: Download complete
# 132ebd5cd5ca: Verifying Checksum
# 132ebd5cd5ca: Download complete
# 00cf30d6c3d7: Verifying Checksum
# 00cf30d6c3d7: Download complete
# 01991399be72: Verifying Checksum
# 01991399be72: Download complete
# 078f888cc2c3: Verifying Checksum
# 078f888cc2c3: Download complete
# a5e3d82f1dff: Verifying Checksum
# a5e3d82f1dff: Download complete
# 87388bef588c: Verifying Checksum
# 87388bef588c: Download complete
# 2363c3a4ec9d: Verifying Checksum
# 2363c3a4ec9d: Download complete
# aabda8a3d51f: Verifying Checksum
# aabda8a3d51f: Download complete
# fe703b657a32: Pull complete
# f9df1fafd224: Pull complete
# a645a4b887f9: Pull complete
# 57db7fe0b522: Pull complete
# 20b5fabe4f63: Pull complete
# 22898513a7dc: Pull complete
# b77f65fcd9d7: Pull complete
# 132ebd5cd5ca: Pull complete
# 01991399be72: Pull complete
# 60c58ca14ef7: Pull complete
# ca339bb1ce1b: Pull complete
# 00cf30d6c3d7: Pull complete
# 078f888cc2c3: Pull complete
# 87388bef588c: Pull complete
# a5e3d82f1dff: Pull complete
# aabda8a3d51f: Pull complete
# 2363c3a4ec9d: Pull complete
# Digest: sha256:67623d337bdb414383e78b42033add4490e443f89480c81603e9b634cde973a5
# Status: Downloaded newer image for centraleacrmpnfcrek.azurecr.io/azureml/azureml_2ab4fbb8a091f131809d127ace412fcb:latest
# 6ea5faeb4a64ade5f3b3ff007213f6dba005d9d5344f9114e0653a814e1d5b1a
#
# Streaming azureml-logs/65_job_prep-tvmps_e3f60327d6e8a7e7008ccb0fc8765117f97b4b0e710094c0c87f2832aa3edeee_d.txt
# ===============================================================================================================
# Entering job preparation. Current time:2020-06-09T18:55:08.044246
# Starting job preparation. Current time:2020-06-09T18:55:08.920314
# Extracting the control code.
# fetching and extracting the control code on master node.
# Retrieving project from snapshot: 065ac46f-0f69-47fc-9e31-2525b0d1f3c9
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# Starting project file download.
# Finished project file download.
# downloadDataStore - Download from datastores if requested.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# Entering context manager injector. Current time:2020-06-09T18:55:14.469572
# Failure while loading azureml_run_type_providers. Failed to load entrypoint hyperdrive = azureml.train.hyperdrive:HyperDriveRun._from_run_dto with exception cannot import name 'OutputDatasetConfig'.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception cannot import name 'OutputTabularDatasetConfig'.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.PipelineRun = azureml.pipeline.core.run:PipelineRun._from_dto with exception cannot import name 'OutputDatasetConfig'.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.ReusedStepRun = azureml.pipeline.core.run:StepRun._from_reused_dto with exception cannot import name 'OutputDatasetConfig'.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint azureml.StepRun = azureml.pipeline.core.run:StepRun._from_dto with exception cannot import name 'OutputDatasetConfig'.
# Initialize DatasetContextManager.
# Starting the daemon thread to refresh tokens in background for process with pid = 104
# Set Dataset input's target path to /tmp/tmp8_sj0hdm
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==0.1.0.15477075 azureml-dataprep==1.7.1a2020060801
# Processing 'input'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'iris.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "439f24a6-1ea0-4beb-8f3a-1e23d8f2493d",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='centraleuap', subscription_id='35f16a99-532a-4a47-9e93-00305f6c40f2', resource_group='rongduan-dev')"
#   }
# }
# Mounting input to /tmp/tmp8_sj0hdm.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception module 'azureml' has no attribute 'dataprep'.
# Mounted input to /tmp/tmp8_sj0hdm
# Processing 'output_13311b31'.
# WARNING - Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception module 'azureml' has no attribute 'dataprep'.
# Mounted output_13311b31 to /tmp/tmp5a1mqhvg.
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# Preparing to call script [ dummy_train.py ] with arguments: ['--datadir', '$input', '--output', '$output_13311b31']
# After variable expansion, calling script [ dummy_train.py ] with arguments: ['--datadir', '/tmp/tmp8_sj0hdm/iris.csv', '--output', '/tmp/tmp5a1mqhvg']
#
# *********************************************************
# Hello Azure ML!
# Argument 1: /tmp/tmp8_sj0hdm/iris.csv
# Argument 2: /tmp/tmp5a1mqhvg
# /tmp/tmp5a1mqhvg created
# Starting the daemon thread to refresh tokens in background for process with pid = 104
#
#
# The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 300.0 seconds
# 2 items cleaning up...
# Cleanup took 0.7063384056091309 seconds
# Enter __exit__ of DatasetContextManager
# Unmounting /tmp/tmp8_sj0hdm.
# Finishing unmounting /tmp/tmp8_sj0hdm.
# Unmounting /tmp/tmp5a1mqhvg.
# Finishing unmounting /tmp/tmp5a1mqhvg.
# Exit __exit__ of DatasetContextManager
#
# Streaming azureml-logs/75_job_post-tvmps_e3f60327d6e8a7e7008ccb0fc8765117f97b4b0e710094c0c87f2832aa3edeee_d.txt
# ===============================================================================================================
# Entering job release. Current time:2020-06-09T18:55:51.652519
# Starting job release. Current time:2020-06-09T18:55:53.477385
# Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 434
# Entering context manager injector. Current time:2020-06-09T18:55:53.498417
# Job release is complete. Current time:2020-06-09T18:55:57.338168
#
# StepRun(Estimator_Train) Execution Summary
# ===========================================
# StepRun( Estimator_Train ) Status: Finished
#
# Warnings:
# This compute target type doesn't support non-Docker runs; overriding run configuration to enable Docker.
# Please enable Docker in the environment section of your run configuration to stop seeing this warning message.
# {'runId': 'bc9d6dd3-f571-4636-be40-6e3d9ef96ab9', 'target': 'mlc', 'status': 'Completed', 'startTimeUtc': '2020-06-09T18:53:58.681242Z', 'endTimeUtc': '2020-06-09T18:56:02.934161Z', 'warnings': [{'message': "This compute target type doesn't support non-Docker runs; overriding run configuration to enable Docker.\nPlease enable Docker in the environment section of your run configuration to stop seeing this warning message."}], 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': '065ac46f-0f69-47fc-9e31-2525b0d1f3c9', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '9a595dbf-0d83-4fad-ac92-98bf93b92a1f', 'azureml.pipelinerunid': '4d72c644-9f57-4352-b110-1c774e1f6956', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': '439f24a6-1ea0-4beb-8f3a-1e23d8f2493d'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': 'cf306479-3f54-4e9d-9193-71997b711482'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'output_13311b31'}}], 'runDefinition': {'script': 'dummy_train.py', 'useAbsolutePath': False, 'arguments': ['--datadir', 'DatasetConsumptionConfig:input', '--output', 'DatasetOutputConfig:output_13311b31'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'mlc', 'dataReferences': {}, 'data': {'input': {'dataLocation': {'dataset': {'id': '439f24a6-1ea0-4beb-8f3a-1e23d8f2493d', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {'output_13311b31': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': 'may_sample/outputdataset'}}, 'mechanism': 'Mount', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}}}}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'environment': {'name': 'Experiment Estimator_sample Environment', 'version': 'Autosave_2020-06-09T18:47:34Z_8ad98c93', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['--index-url https://azuremlsdktestpypi.azureedge.net/Create-Dev-Index/15335858/', '--extra-index-url https://pypi.python.org/simple', 'azureml-sdk~=0.1.0.15477075']}], 'name': 'azureml_becb75071dac89d1dfc4639fd26ab126'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200423.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs']}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'argumen ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '4d72c644-9f57-4352-b110-1c774e1f6956', 'status': 'Completed', 'startTimeUtc': '2020-06-09T18:47:26.386289Z', 'endTimeUtc': '2020-06-09T18:58:00.621285Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://centralestoragedlzbbsxk.blob.core.windows.net/azureml/ExperimentRun/dcid.4d72c644-9f57-4352-b110-1c774e1f6956/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=HTfBAANWxr3KSx8inUV8MqZDq4mHXxkDhr7H3GMWcEY%3D&skoid=e3f42e2c-d581-4b65-a966-631cfa961328&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2020-06-09T04%3A03%3A56Z&ske=2020-06-10T03%3A09%3A51Z&sks=b&skv=2019-02-02&st=2020-06-09T18%3A48%3A07Z&se=2020-06-10T02%3A58%3A07Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://centralestoragedlzbbsxk.blob.core.windows.net/azureml/ExperimentRun/dcid.4d72c644-9f57-4352-b110-1c774e1f6956/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=NFulXliRQjmPh4vmoNlnxvDbe5AqoV0pBdA5vN1fUQI%3D&skoid=e3f42e2c-d581-4b65-a966-631cfa961328&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2020-06-09T04%3A03%3A56Z&ske=2020-06-10T03%3A09%3A51Z&sks=b&skv=2019-02-02&st=2020-06-09T18%3A48%3A07Z&se=2020-06-10T02%3A58%3A07Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://centralestoragedlzbbsxk.blob.core.windows.net/azureml/ExperimentRun/dcid.4d72c644-9f57-4352-b110-1c774e1f6956/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=d%2Faw2j27YDzkmIcceVGmkoHqrSWw9YIuUs2MnWltFmI%3D&skoid=e3f42e2c-d581-4b65-a966-631cfa961328&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2020-06-09T04%3A03%3A56Z&ske=2020-06-10T03%3A09%3A51Z&sks=b&skv=2019-02-02&st=2020-06-09T18%3A48%3A07Z&se=2020-06-10T02%3A58%3A07Z&sp=r'}}
# 'Finished'
